# %%
import matplotlib.pyplot as plt
from bpd.prior import sample_mag_ellip_prior, sample_ellip_prior, sample_synthetic_sheared_ellips_unclipped, sample_synthetic_sheared_ellips_clipped
from jax import random

# %%
rng_key = random.key(42)

# %%
e_samples = sample_mag_ellip_prior(rng_key, sigma=0.3, n=100_000)
e_samples.shape
# Out:
# (100000,)

# %%
_ = plt.hist(e_samples, bins=51, histtype='step')

# %%
e_samples.shape
# Out:
# (100000, 2)

# %%
plt.figure(figsize=(7,7))
e_samples, _, _ = sample_synthetic_sheared_ellips_clipped(rng_key, g=(0.02, 0.0), sigma_e=0.3, sigma_m=0.1, n=100_000, m=1,)
e_samples.shape
# Out:
# (100000, 1, 2)

# %%
plt.scatter(e_samples[:, 0, 0], e_samples[:, 0, 1], marker='o', s=5, alpha=0.25)
